# %%
import pandas as pd

# %%
base_url = "https://health.data.ny.gov/resource/rmwa-zns4"

# %%
pd.read_json(base_url + "?" + "$select=count(*)")
# Out:
#      count
# 0  2365208

# %%
url_count_by_disposition = base_url + "?" + "$select=count(*),patient_disposition&$group=patient_disposition"
print(url_count_by_disposition)
pd.read_json(url_count_by_disposition)
# Out:
# https://health.data.ny.gov/resource/rmwa-zns4?$select=count(*),patient_disposition&$group=patient_disposition
#       count                    patient_disposition
# 0       152         Medicaid Cert Nursing Facility
# 1       121               Critical Access Hospital
# 2      3789  Medicare Cert Long Term Care Hospital
# 3      2504   Cancer Center or Children's Hospital
# 4      1544  Hosp Basd Medicare Approved Swing Bed
# 5       725           Federal Health Care Facility
# 6      8441                Another Type Not Listed
# 7      3731                  Court/Law Enforcement
# 8     10540                         Hospice - Home
# 9      6268  Facility w/ Custodial/Supportive Care
# 10    12565   Psychiatric Hospital or Unit of Hosp
# 11    41524      Inpatient Rehabilitation Facility
# 12    12513             Hospice - Medical Facility
# 13    50913                                Expired
# 14   317027           Home w/ Home Health Services
# 15    40817                    Short-term Hospital
# 16  1581401                      Home or Self Care
# 17    47012            Left Against Medical Advice
# 18   223621                   Skilled Nursing Home

# %%
url_facility_discharge_count = base_url + "?$select=count(*),facility_name&$group=facility_name"
print(url_facility_discharge_count)
facility_discharge_count_df = pd.read_json(url_facility_discharge_count)
facility_discharge_count_df.columns = ["discharge_count", "facility_name"]
# Out:
# https://health.data.ny.gov/resource/rmwa-zns4?$select=count(*),facility_name&$group=facility_name

# %%
facility_discharge_count_df.head(5)
# Out:
#    discharge_count                                      facility_name
# 0               86                         Cuba Memorial Hospital Inc
# 1             1966  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 2             5262                             Olean General Hospital
# 3             2857                           Brooks Memorial Hospital
# 4             1227  Womans Christian Assoc Hospital - WCA Hosp at ...

# %%
url_facility_expired_count = base_url + "?$select=count(*),facility_name&$group=facility_name&patient_disposition=Expired"
print(url_facility_expired_count)
facility_expired_count_df = pd.read_json(url_facility_expired_count)
facility_expired_count_df.columns = ["expired_count", "facility_name"]
# Out:
# https://health.data.ny.gov/resource/rmwa-zns4?$select=count(*),facility_name&$group=facility_name&patient_disposition=Expired

# %%
facility_expired_count_df.head(5)
# Out:
#    expired_count                                      facility_name
# 0             52  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 1            171                             Olean General Hospital
# 2             73                           Brooks Memorial Hospital
# 3            157                      Woman's Christian Association
# 4              1                    Westfield Memorial Hospital Inc

# %%
facility_discharged_with_expired_df = pd.merge(facility_discharge_count_df, facility_expired_count_df, on="facility_name")

# %%
facility_discharged_with_expired_df["expired_rate_per_discharge"] = facility_discharged_with_expired_df["expired_count"] / facility_discharged_with_expired_df["discharge_count"]

# %%
facility_discharged_with_expired_df.sort_values("expired_rate_per_discharge", ascending=False).head(25)
# Out:
#      discharge_count                                      facility_name  \
# 125             2900                               Calvary Hospital Inc
# 30                54                          Monroe Community Hospital
# 153              252                 Henry J. Carter Specialty Hospital
# 73               189                                  O'Connor Hospital
# 4                 18                    Westfield Memorial Hospital Inc
# 40               759  Soldiers and Sailors Memorial Hospital of Yate...
# 143            10125                   Mount Sinai Beth Israel Brooklyn
# 38               556                Ira Davenport Memorial Hospital Inc
# 184             6013                                St. Joseph Hospital
# 167             8884               St Johns Episcopal Hospital So Shore
# 32              3642                            Geneva General Hospital
# 87             14150                                     Ellis Hospital
# 18              1734                          Degraff Memorial Hospital
# 14              3957     Sisters of Charity Hospital - St Joseph Campus
# 12              7713                             Kenmore Mercy Hospital
# 9              21186                          Mercy Hospital of Buffalo
# 59             19705     University Hospital SUNY Health Science Center
# 6              21928                           Buffalo General Hospital
# 187            13760    Brookhaven Memorial Hospital Medical Center Inc
# 107             7795            HealthAlliance Hospital Broadway Campus
# 33              2237                Clifton Springs Hospital and Clinic
# 168            31218         New York Hospital Medical Center of Queens
# 94             20302                     Vassar Brothers Medical Center
# 76               271  The University of Vermont Health Network - Eli...
# 130            15815                  Brookdale Hospital Medical Center
#
#      expired_count  expired_rate_per_discharge
# 125           2391                    0.824483
# 30               7                    0.129630
# 153             17                    0.067460
# 73              12                    0.063492
# 4                1                    0.055556
# 40              42                    0.055336
# 143            483                    0.047704
# 38              26                    0.046763
# 184            275                    0.045734
# 167            403                    0.045362
# 32             165                    0.045305
# 87             632                    0.044664
# 18              70                    0.040369
# 14             159                    0.040182
# 12             303                    0.039284
# 9              828                    0.039082
# 59             745                    0.037808
# 6              825                    0.037623
# 187            515                    0.037427
# 107            283                    0.036305
# 33              81                    0.036209
# 168           1046                    0.033506
# 94             676                    0.033297
# 76               9                    0.033210
# 130            522                    0.033007

# %%
facility_discharged_with_expired_df.sort_values("expired_rate_per_discharge", ascending=False)[facility_discharged_with_expired_df["discharge_count"] >= 1000]
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#      discharge_count                                      facility_name  \
# 125             2900                               Calvary Hospital Inc
# 143            10125                   Mount Sinai Beth Israel Brooklyn
# 184             6013                                St. Joseph Hospital
# 167             8884               St Johns Episcopal Hospital So Shore
# 32              3642                            Geneva General Hospital
# 87             14150                                     Ellis Hospital
# 18              1734                          Degraff Memorial Hospital
# 14              3957     Sisters of Charity Hospital - St Joseph Campus
# 12              7713                             Kenmore Mercy Hospital
# 9              21186                          Mercy Hospital of Buffalo
# 59             19705     University Hospital SUNY Health Science Center
# 6              21928                           Buffalo General Hospital
# 187            13760    Brookhaven Memorial Hospital Medical Center Inc
# 107             7795            HealthAlliance Hospital Broadway Campus
# 33              2237                Clifton Springs Hospital and Clinic
# 168            31218         New York Hospital Medical Center of Queens
# 94             20302                     Vassar Brothers Medical Center
# 130            15815                  Brookdale Hospital Medical Center
# 1               5262                             Olean General Hospital
# 10              4466                      Roswell Park Cancer Institute
# 44              4984                           Auburn Memorial Hospital
# 185             8625                                 Plainview Hospital
# 83              9748                      Mary Imogene Bassett Hospital
# 133            15436                              Coney Island Hospital
# 112             7531                   Montefiore New Rochelle Hospital
# 61              4230                                    Oswego Hospital
# 132             6982       New York Community Hospital of Brooklyn, Inc
# 100             6650                             Putnam Hospital Center
# 152            22051   Memorial Hospital for Cancer and Allied Diseases
# 140             8440                   Kingsbrook Jewish Medical Center
# ..               ...                                                ...
# 27             18918                                  Highland Hospital
# 148            11837                             Harlem Hospital Center
# 121            20327                              Jacobi Medical Center
# 115             9852                      Northern Westchester Hospital
# 41              4370  United Health Services Hospitals Inc. - Bingha...
# 84              3985                                St. Mary's Hospital
# 70             24662                                 St Peters Hospital
# 39              5315                    Newark-Wayne Community Hospital
# 122            16929       Montefiore Medical Center-Wakefield Hospital
# 124            24229             Lincoln Medical & Mental Health Center
# 126            16585                                  SBH Health System
# 151            31778                                Lenox Hill Hospital
# 53              1518                    Community Memorial Hospital Inc
# 146            27532                           Bellevue Hospital Center
# 50              1023                         Carthage Area Hospital Inc
# 191            10208                                St Charles Hospital
# 157            31795                               NYU Hospitals Center
# 62              2943                     Claxton-Hepburn Medical Center
# 51              1641                      Lewis County General Hospital
# 159            26534                              Mount Sinai Roosevelt
# 128             5432                       North Central Bronx Hospital
# 154            11613                       Metropolitan Hospital Center
# 7              12742           Women And Children's Hospital Of Buffalo
# 174            17042  Long Island Jewish Schneiders Children's Hospi...
# 88              2310       Sunnyview Hospital and Rehabilitation Center
# 92              2312                            The Burdett Care Center
# 196             3475           Abortion Record - Facility Name Redacted
# 89              5503  Ellis Hospital - Bellevue Woman's Care Center ...
# 149             6129                    NYU Hospital for Joint Diseases
# 150            14532                       Hospital for Special Surgery
#
#      expired_count  expired_rate_per_discharge
# 125           2391                    0.824483
# 143            483                    0.047704
# 184            275                    0.045734
# 167            403                    0.045362
# 32             165                    0.045305
# 87             632                    0.044664
# 18              70                    0.040369
# 14             159                    0.040182
# 12             303                    0.039284
# 9              828                    0.039082
# 59             745                    0.037808
# 6              825                    0.037623
# 187            515                    0.037427
# 107            283                    0.036305
# 33              81                    0.036209
# 168           1046                    0.033506
# 94             676                    0.033297
# 130            522                    0.033007
# 1              171                    0.032497
# 10             145                    0.032468
# 44             160                    0.032103
# 185            275                    0.031884
# 83             304                    0.031186
# 133            481                    0.031161
# 112            230                    0.030540
# 61             128                    0.030260
# 132            210                    0.030077
# 100            198                    0.029774
# 152            650                    0.029477
# 140            247                    0.029265
# ..             ...                         ...
# 27             256                    0.013532
# 148            157                    0.013263
# 121            256                    0.012594
# 115            124                    0.012586
# 41              55                    0.012586
# 84              50                    0.012547
# 70             301                    0.012205
# 39              63                    0.011853
# 122            200                    0.011814
# 124            285                    0.011763
# 126            194                    0.011697
# 151            348                    0.010951
# 53              15                    0.009881
# 146            266                    0.009661
# 50               9                    0.008798
# 191             83                    0.008131
# 157            252                    0.007926
# 62              23                    0.007815
# 51              12                    0.007313
# 159            168                    0.006331
# 128             29                    0.005339
# 154             55                    0.004736
# 7               60                    0.004709
# 174             75                    0.004401
# 88               8                    0.003463
# 92               2                    0.000865
# 196              2                    0.000576
# 89               1                    0.000182
# 149              1                    0.000163
# 150              1                    0.000069
#
# [174 rows x 4 columns]

# %%
hospital_url = base_url + "?facility_name=Coney%20Island%20Hospital"
print(hospital_url)
hospital_df = pd.read_json(hospital_url)
# Out:
# https://health.data.ny.gov/resource/rmwa-zns4?facility_name=Coney%20Island%20Hospital

# %%
hospital_df.head(10)
# Out:
#   abortion_edit_indicator admit_day_of_week    age_group  apr_drg_code  \
# 0                       N               WED     30 to 49           753
# 1                       N               WED     50 to 69           750
# 2                       N               WED     30 to 49           140
# 3                       N               WED  70 or Older           720
# 4                       N               WED  70 or Older           140
# 5                       N               WED     50 to 69           190
# 6                       N               WED     30 to 49           750
# 7                       N               WED  70 or Older           463
# 8                       N               WED     30 to 49           750
# 9                       N               WED  70 or Older           720
#
#                      apr_drg_description  apr_mdc_code  \
# 0                      BIPOLAR DISORDERS            19
# 1                          SCHIZOPHRENIA            19
# 2  CHRONIC OBSTRUCTIVE PULMONARY DISEASE             4
# 3   SEPTICEMIA & DISSEMINATED INFECTIONS            18
# 4  CHRONIC OBSTRUCTIVE PULMONARY DISEASE             4
# 5            ACUTE MYOCARDIAL INFARCTION             5
# 6                          SCHIZOPHRENIA            19
# 7      KIDNEY & URINARY TRACT INFECTIONS            11
# 8                          SCHIZOPHRENIA            19
# 9   SEPTICEMIA & DISSEMINATED INFECTIONS            18
#
#                                  apr_mdc_description  \
# 0                      Mental Diseases and Disorders
# 1                      Mental Diseases and Disorders
# 2   Diseases and Disorders of the Respiratory System
# 3  Infectious and Parasitic Diseases, Systemic or...
# 4   Diseases and Disorders of the Respiratory System
# 5   Diseases and Disorders of the Circulatory System
# 6                      Mental Diseases and Disorders
# 7  Diseases and Disorders of the Kidney and Urina...
# 8                      Mental Diseases and Disorders
# 9  Infectious and Parasitic Diseases, Systemic or...
#
#   apr_medical_surgical_description apr_risk_of_mortality  \
# 0                          Medical                 Minor
# 1                          Medical                 Minor
# 2                          Medical                 Minor
# 3                          Medical                 Major
# 4                          Medical                 Major
# 5                          Medical                 Major
# 6                          Medical                 Minor
# 7                          Medical              Moderate
# 8                          Medical                 Minor
# 9                          Medical               Extreme
#
#    apr_severity_of_illness_code        ...         \
# 0                             2        ...
# 1                             1        ...
# 2                             2        ...
# 3                             3        ...
# 4                             3        ...
# 5                             3        ...
# 6                             1        ...
# 7                             2        ...
# 8                             2        ...
# 9                             4        ...
#
#   operating_provider_license_number           patient_disposition  \
# 0                          234646.0             Home or Self Care
# 1                          218003.0             Home or Self Care
# 2                          235776.0             Home or Self Care
# 3                          217963.0          Skilled Nursing Home
# 4                          221582.0             Home or Self Care
# 5                          199382.0           Short-term Hospital
# 6                          204304.0             Home or Self Care
# 7                          241803.0  Home w/ Home Health Services
# 8                          218003.0             Home or Self Care
# 9                          235776.0          Skilled Nursing Home
#
#                      race  source_of_payment_1 source_of_payment_2  \
# 0              Other Race             Medicaid            Medicaid
# 1              Other Race             Medicare            Medicaid
# 2  Black/African American             Medicare            Medicare
# 3                   White             Medicare            Medicaid
# 4  Black/African American             Medicare            Medicare
# 5                   White             Medicare                 NaN
# 6              Other Race             Medicaid                 NaN
# 7                   White             Medicare            Medicare
# 8                   White             Self-Pay                 NaN
# 9                   White             Medicare            Medicare
#
#         source_of_payment_3 total_charges total_costs  type_of_admission  \
# 0                       NaN      23450.98    17820.05          Emergency
# 1                       NaN      30716.00    23340.63          Emergency
# 2                  Medicaid      30174.63    22929.25          Emergency
# 3                       NaN      30204.59    22952.01          Emergency
# 4                  Medicaid      26651.11    20251.78          Emergency
# 5                       NaN      10611.60     8063.60          Emergency
# 6                       NaN      20958.05    15925.71          Emergency
# 7                  Medicaid      27150.89    20631.55          Emergency
# 8                       NaN      15168.03    11525.96          Emergency
# 9  Private Health Insurance      30454.78    23142.13          Emergency
#
#   zip_code_3_digits
# 0               112
# 1               112
# 2               112
# 3               112
# 4               112
# 5               112
# 6               112
# 7               112
# 8               112
# 9               112
#
# [10 rows x 38 columns]

# %%
hospital_df["apr_drg_with_code"] = hospital_df.apply( lambda x: str("00" + str(int(x["apr_drg_code"])))[-3:] + " - " + x["apr_drg_description"], axis=1)

# %%
hospital_df["length_of_stay"] = hospital_df.apply(
    lambda x: 120 if "120 +" == x["length_of_stay"] else int(x["length_of_stay"]), axis=1)

# %%
import numpy as np
hospital_df.groupby("apr_drg_with_code")["length_of_stay"].agg({"discharges": np.size, "total_days": np.sum, 
                                                                "mean_length_of_stay": np.mean})
# Out:
#                                                     discharges  total_days  \
# apr_drg_with_code
# 005 - TRACHEOSTOMY W MV 96+ HOURS W/O EXTENSIVE...           8         446
# 021 - CRANIOTOMY EXCEPT FOR TRAUMA                           3          40
# 026 - OTHER NERVOUS SYSTEM & RELATED PROCEDURES              1           9
# 041 - NERVOUS SYSTEM MALIGNANCY                              2          29
# 042 - DEGENERATIVE NERVOUS SYSTEM DISORDERS EXC...           1           6
# 044 - INTRACRANIAL HEMORRHAGE                                2          21
# 045 - CVA & PRECEREBRAL OCCLUSION W INFARCT                 17         146
# 047 - TRANSIENT ISCHEMIA                                     9          46
# 048 - PERIPHERAL, CRANIAL & AUTONOMIC NERVE DIS...           3           7
# 050 - NON-BACTERIAL INFECTIONS OF NERVOUS SYSTE...           1           6
# 053 - SEIZURE                                               20          72
# 055 - HEAD TRAUMA W COMA >1 HR OR HEMORRHAGE                 6          20
# 058 - OTHER DISORDERS OF NERVOUS SYSTEM                      5          26
# 080 - ACUTE MAJOR EYE INFECTIONS                             2          13
# 111 - VERTIGO & OTHER LABYRINTH DISORDERS                    5          25
# 113 - INFECTIONS OF UPPER RESPIRATORY TRACT                  7          24
# 115 - OTHER EAR, NOSE, MOUTH,THROAT & CRANIAL/F...           4          18
# 130 - RESPIRATORY SYSTEM DIAGNOSIS W VENTILATOR...           6         139
# 133 - PULMONARY EDEMA & RESPIRATORY FAILURE                 12         148
# 134 - PULMONARY EMBOLISM                                     1           4
# 136 - RESPIRATORY MALIGNANCY                                 3          28
# 137 - MAJOR RESPIRATORY INFECTIONS & INFLAMMATIONS           6          77
# 138 - BRONCHIOLITIS & RSV PNEUMONIA                          1          14
# 139 - OTHER PNEUMONIA                                       22         218
# 140 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE                 30         202
# 141 - ASTHMA                                                11          33
# 142 - INTERSTITIAL LUNG DISEASE                              1          15
# 143 - OTHER RESPIRATORY DIAGNOSES EXCEPT SIGNS,...           3          49
# 144 - RESPIRATORY SIGNS, SYMPTOMS & MINOR DIAGN...           8          32
# 173 - OTHER VASCULAR PROCEDURES                              2          26
# ...                                                        ...         ...
# 639 - NEONATE BIRTHWT >2499G W OTHER SIGNIFICAN...           2          13
# 640 - NEONATE BIRTHWT >2499G, NORMAL NEWBORN OR...          50         124
# 662 - SICKLE CELL ANEMIA CRISIS                              2          27
# 663 - OTHER ANEMIA & DISORDERS OF BLOOD & BLOOD...           6          55
# 693 - CHEMOTHERAPY                                           1           5
# 710 - INFECTIOUS & PARASITIC DISEASES INCLUDING...           6         174
# 720 - SEPTICEMIA & DISSEMINATED INFECTIONS                  34         222
# 721 - POST-OPERATIVE, POST-TRAUMATIC, OTHER DEV...           3          54
# 723 - VIRAL ILLNESS                                          1           2
# 750 - SCHIZOPHRENIA                                         42         984
# 751 - MAJOR DEPRESSIVE DISORDERS & OTHER/UNSPEC...          16         369
# 753 - BIPOLAR DISORDERS                                     22         237
# 754 - DEPRESSION EXCEPT MAJOR DEPRESSIVE DISORDER            8          59
# 756 - ACUTE ANXIETY & DELIRIUM STATES                        4          15
# 757 - ORGANIC MENTAL HEALTH DISTURBANCES                     2           5
# 770 - DRUG & ALCOHOL ABUSE OR DEPENDENCE, LEFT ...          16          34
# 773 - OPIOID ABUSE & DEPENDENCE                             29         135
# 774 - COCAINE ABUSE & DEPENDENCE                             2           9
# 775 - ALCOHOL ABUSE & DEPENDENCE                            31         133
# 812 - POISONING OF MEDICINAL AGENTS                          2           7
# 815 - OTHER INJURY, POISONING & TOXIC EFFECT DI...           1           2
# 816 - TOXIC EFFECTS OF NON-MEDICINAL SUBSTANCES              3          10
# 843 - EXTENSIVE 3RD DEGREE OR FULL THICKNESS BU...           1           2
# 850 - PROCEDURE W DIAG OF REHAB, AFTERCARE OR O...           1           4
# 861 - SIGNS, SYMPTOMS & OTHER FACTORS INFLUENCI...           8          42
# 890 - HIV W MULTIPLE MAJOR HIV RELATED CONDITIONS            1         118
# 894 - HIV W ONE SIGNIF HIV COND OR W/O SIGNIF R...           1           9
# 912 - MUSCULOSKELETAL & OTHER PROCEDURES FOR MU...           1          11
# 951 - MODERATELY EXTENSIVE PROCEDURE UNRELATED ...           3          78
# 952 - NONEXTENSIVE PROCEDURE UNRELATED TO PRINC...           3         187
#
#                                                     mean_length_of_stay
# apr_drg_with_code
# 005 - TRACHEOSTOMY W MV 96+ HOURS W/O EXTENSIVE...            55.750000
# 021 - CRANIOTOMY EXCEPT FOR TRAUMA                            13.333333
# 026 - OTHER NERVOUS SYSTEM & RELATED PROCEDURES                9.000000
# 041 - NERVOUS SYSTEM MALIGNANCY                               14.500000
# 042 - DEGENERATIVE NERVOUS SYSTEM DISORDERS EXC...             6.000000
# 044 - INTRACRANIAL HEMORRHAGE                                 10.500000
# 045 - CVA & PRECEREBRAL OCCLUSION W INFARCT                    8.588235
# 047 - TRANSIENT ISCHEMIA                                       5.111111
# 048 - PERIPHERAL, CRANIAL & AUTONOMIC NERVE DIS...             2.333333
# 050 - NON-BACTERIAL INFECTIONS OF NERVOUS SYSTE...             6.000000
# 053 - SEIZURE                                                  3.600000
# 055 - HEAD TRAUMA W COMA >1 HR OR HEMORRHAGE                   3.333333
# 058 - OTHER DISORDERS OF NERVOUS SYSTEM                        5.200000
# 080 - ACUTE MAJOR EYE INFECTIONS                               6.500000
# 111 - VERTIGO & OTHER LABYRINTH DISORDERS                      5.000000
# 113 - INFECTIONS OF UPPER RESPIRATORY TRACT                    3.428571
# 115 - OTHER EAR, NOSE, MOUTH,THROAT & CRANIAL/F...             4.500000
# 130 - RESPIRATORY SYSTEM DIAGNOSIS W VENTILATOR...            23.166667
# 133 - PULMONARY EDEMA & RESPIRATORY FAILURE                   12.333333
# 134 - PULMONARY EMBOLISM                                       4.000000
# 136 - RESPIRATORY MALIGNANCY                                   9.333333
# 137 - MAJOR RESPIRATORY INFECTIONS & INFLAMMATIONS            12.833333
# 138 - BRONCHIOLITIS & RSV PNEUMONIA                           14.000000
# 139 - OTHER PNEUMONIA                                          9.909091
# 140 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE                    6.733333
# 141 - ASTHMA                                                   3.000000
# 142 - INTERSTITIAL LUNG DISEASE                               15.000000
# 143 - OTHER RESPIRATORY DIAGNOSES EXCEPT SIGNS,...            16.333333
# 144 - RESPIRATORY SIGNS, SYMPTOMS & MINOR DIAGN...             4.000000
# 173 - OTHER VASCULAR PROCEDURES                               13.000000
# ...                                                                 ...
# 639 - NEONATE BIRTHWT >2499G W OTHER SIGNIFICAN...             6.500000
# 640 - NEONATE BIRTHWT >2499G, NORMAL NEWBORN OR...             2.480000
# 662 - SICKLE CELL ANEMIA CRISIS                               13.500000
# 663 - OTHER ANEMIA & DISORDERS OF BLOOD & BLOOD...             9.166667
# 693 - CHEMOTHERAPY                                             5.000000
# 710 - INFECTIOUS & PARASITIC DISEASES INCLUDING...            29.000000
# 720 - SEPTICEMIA & DISSEMINATED INFECTIONS                     6.529412
# 721 - POST-OPERATIVE, POST-TRAUMATIC, OTHER DEV...            18.000000
# 723 - VIRAL ILLNESS                                            2.000000
# 750 - SCHIZOPHRENIA                                           23.428571
# 751 - MAJOR DEPRESSIVE DISORDERS & OTHER/UNSPEC...            23.062500
# 753 - BIPOLAR DISORDERS                                       10.772727
# 754 - DEPRESSION EXCEPT MAJOR DEPRESSIVE DISORDER              7.375000
# 756 - ACUTE ANXIETY & DELIRIUM STATES                          3.750000
# 757 - ORGANIC MENTAL HEALTH DISTURBANCES                       2.500000
# 770 - DRUG & ALCOHOL ABUSE OR DEPENDENCE, LEFT ...             2.125000
# 773 - OPIOID ABUSE & DEPENDENCE                                4.655172
# 774 - COCAINE ABUSE & DEPENDENCE                               4.500000
# 775 - ALCOHOL ABUSE & DEPENDENCE                               4.290323
# 812 - POISONING OF MEDICINAL AGENTS                            3.500000
# 815 - OTHER INJURY, POISONING & TOXIC EFFECT DI...             2.000000
# 816 - TOXIC EFFECTS OF NON-MEDICINAL SUBSTANCES                3.333333
# 843 - EXTENSIVE 3RD DEGREE OR FULL THICKNESS BU...             2.000000
# 850 - PROCEDURE W DIAG OF REHAB, AFTERCARE OR O...             4.000000
# 861 - SIGNS, SYMPTOMS & OTHER FACTORS INFLUENCI...             5.250000
# 890 - HIV W MULTIPLE MAJOR HIV RELATED CONDITIONS            118.000000
# 894 - HIV W ONE SIGNIF HIV COND OR W/O SIGNIF R...             9.000000
# 912 - MUSCULOSKELETAL & OTHER PROCEDURES FOR MU...            11.000000
# 951 - MODERATELY EXTENSIVE PROCEDURE UNRELATED ...            26.000000
# 952 - NONEXTENSIVE PROCEDURE UNRELATED TO PRINC...            62.333333
#
# [139 rows x 3 columns]

# %%
apr_drgs_expired_df=hospital_df[hospital_df["patient_disposition"] == "Expired"].groupby("apr_drg_with_code")["length_of_stay"].count()

# %%
pd.merge(apr)
