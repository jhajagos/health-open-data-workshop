# %% [markdown]
# In this notebook we will calculate the rate of in-hospital mortality across all facilities in New York State. Then we will look at a single hospital's mortality data by [APR DRG](http://solutions.3m.com/wps/portal/3M/en_US/Health-Information-Systems/HIS/Products-and-Services/Products-List-A-Z/APR-DRG-Software/). APR DRGs are a form of [diagnosis related group](https://en.wikipedia.org/wiki/Diagnosis-related_group) which are often tied to payment. They take into account both the diagnoses and procedures performed.

# %%
import pandas as pd

# %% [markdown]
# We leverage the server side to do the heavy lifting in computing the in-hospital mortality rates across the state.

# %%
base_url = "https://health.data.ny.gov/resource/rmwa-zns4"

# %%
pd.read_json(base_url + "?" + "$select=count(*)")
# Out:
#      count
# 0  2365208

# %%
url_count_by_disposition = base_url + "?" + "$select=count(*),patient_disposition&$group=patient_disposition"
print(url_count_by_disposition)
pd.read_json(url_count_by_disposition)
# Out:
# https://health.data.ny.gov/resource/rmwa-zns4?$select=count(*),patient_disposition&$group=patient_disposition
#       count                    patient_disposition
# 0       152         Medicaid Cert Nursing Facility
# 1       121               Critical Access Hospital
# 2      3789  Medicare Cert Long Term Care Hospital
# 3      2504   Cancer Center or Children's Hospital
# 4      1544  Hosp Basd Medicare Approved Swing Bed
# 5       725           Federal Health Care Facility
# 6      8441                Another Type Not Listed
# 7      3731                  Court/Law Enforcement
# 8     10540                         Hospice - Home
# 9      6268  Facility w/ Custodial/Supportive Care
# 10    12565   Psychiatric Hospital or Unit of Hosp
# 11    41524      Inpatient Rehabilitation Facility
# 12    12513             Hospice - Medical Facility
# 13    50913                                Expired
# 14   317027           Home w/ Home Health Services
# 15    40817                    Short-term Hospital
# 16  1581401                      Home or Self Care
# 17    47012            Left Against Medical Advice
# 18   223621                   Skilled Nursing Home

# %%
url_facility_discharge_count = base_url + "?$select=count(*),facility_name&$group=facility_name"
print(url_facility_discharge_count)
facility_discharge_count_df = pd.read_json(url_facility_discharge_count)
facility_discharge_count_df.columns = ["discharge_count", "facility_name"]
# Out:
# https://health.data.ny.gov/resource/rmwa-zns4?$select=count(*),facility_name&$group=facility_name

# %%
facility_discharge_count_df.head(5)
# Out:
#    discharge_count                                      facility_name
# 0               86                         Cuba Memorial Hospital Inc
# 1             1966  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 2             5262                             Olean General Hospital
# 3             2857                           Brooks Memorial Hospital
# 4             1227  Womans Christian Assoc Hospital - WCA Hosp at ...

# %% [markdown]
# We pull separately the mortality data from SPARCS and then merge / join the data to the discharge count.

# %%
url_facility_expired_count = base_url + "?$select=count(*),facility_name&$group=facility_name&patient_disposition=Expired"
print(url_facility_expired_count)
facility_expired_count_df = pd.read_json(url_facility_expired_count)
facility_expired_count_df.columns = ["expired_count", "facility_name"]
# Out:
# https://health.data.ny.gov/resource/rmwa-zns4?$select=count(*),facility_name&$group=facility_name&patient_disposition=Expired

# %%
facility_expired_count_df.head(5)
# Out:
#    expired_count                                      facility_name
# 0             52  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 1            171                             Olean General Hospital
# 2             73                           Brooks Memorial Hospital
# 3            157                      Woman's Christian Association
# 4              1                    Westfield Memorial Hospital Inc

# %%
facility_discharged_with_expired_df = pd.merge(facility_discharge_count_df, facility_expired_count_df, on="facility_name")

# %%
facility_discharged_with_expired_df["expired_rate_per_discharge"] = facility_discharged_with_expired_df["expired_count"] / facility_discharged_with_expired_df["discharge_count"]

# %% [markdown]
# Mortality rates will vary by type of services that a hospital performs. For example a hospital with a large number of live births will have a lower mortality rate. This should be considered a first look of the data and more significant conclusions can be drawn when looking at the APR DRG level.

# %%
facility_discharged_with_expired_df.sort_values("expired_rate_per_discharge", ascending=False).head(25)
# Out:
#      discharge_count                                      facility_name  \
# 125             2900                               Calvary Hospital Inc
# 30                54                          Monroe Community Hospital
# 153              252                 Henry J. Carter Specialty Hospital
# 73               189                                  O'Connor Hospital
# 4                 18                    Westfield Memorial Hospital Inc
# 40               759  Soldiers and Sailors Memorial Hospital of Yate...
# 143            10125                   Mount Sinai Beth Israel Brooklyn
# 38               556                Ira Davenport Memorial Hospital Inc
# 184             6013                                St. Joseph Hospital
# 167             8884               St Johns Episcopal Hospital So Shore
# 32              3642                            Geneva General Hospital
# 87             14150                                     Ellis Hospital
# 18              1734                          Degraff Memorial Hospital
# 14              3957     Sisters of Charity Hospital - St Joseph Campus
# 12              7713                             Kenmore Mercy Hospital
# 9              21186                          Mercy Hospital of Buffalo
# 59             19705     University Hospital SUNY Health Science Center
# 6              21928                           Buffalo General Hospital
# 187            13760    Brookhaven Memorial Hospital Medical Center Inc
# 107             7795            HealthAlliance Hospital Broadway Campus
# 33              2237                Clifton Springs Hospital and Clinic
# 168            31218         New York Hospital Medical Center of Queens
# 94             20302                     Vassar Brothers Medical Center
# 76               271  The University of Vermont Health Network - Eli...
# 130            15815                  Brookdale Hospital Medical Center
#
#      expired_count  expired_rate_per_discharge
# 125           2391                    0.824483
# 30               7                    0.129630
# 153             17                    0.067460
# 73              12                    0.063492
# 4                1                    0.055556
# 40              42                    0.055336
# 143            483                    0.047704
# 38              26                    0.046763
# 184            275                    0.045734
# 167            403                    0.045362
# 32             165                    0.045305
# 87             632                    0.044664
# 18              70                    0.040369
# 14             159                    0.040182
# 12             303                    0.039284
# 9              828                    0.039082
# 59             745                    0.037808
# 6              825                    0.037623
# 187            515                    0.037427
# 107            283                    0.036305
# 33              81                    0.036209
# 168           1046                    0.033506
# 94             676                    0.033297
# 76               9                    0.033210
# 130            522                    0.033007

# %%
facility_discharged_with_expired_df.sort_values("expired_rate_per_discharge", ascending=False)[facility_discharged_with_expired_df["discharge_count"] >= 1000]
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#      discharge_count                                      facility_name  \
# 125             2900                               Calvary Hospital Inc
# 143            10125                   Mount Sinai Beth Israel Brooklyn
# 184             6013                                St. Joseph Hospital
# 167             8884               St Johns Episcopal Hospital So Shore
# 32              3642                            Geneva General Hospital
# 87             14150                                     Ellis Hospital
# 18              1734                          Degraff Memorial Hospital
# 14              3957     Sisters of Charity Hospital - St Joseph Campus
# 12              7713                             Kenmore Mercy Hospital
# 9              21186                          Mercy Hospital of Buffalo
# 59             19705     University Hospital SUNY Health Science Center
# 6              21928                           Buffalo General Hospital
# 187            13760    Brookhaven Memorial Hospital Medical Center Inc
# 107             7795            HealthAlliance Hospital Broadway Campus
# 33              2237                Clifton Springs Hospital and Clinic
# 168            31218         New York Hospital Medical Center of Queens
# 94             20302                     Vassar Brothers Medical Center
# 130            15815                  Brookdale Hospital Medical Center
# 1               5262                             Olean General Hospital
# 10              4466                      Roswell Park Cancer Institute
# 44              4984                           Auburn Memorial Hospital
# 185             8625                                 Plainview Hospital
# 83              9748                      Mary Imogene Bassett Hospital
# 133            15436                              Coney Island Hospital
# 112             7531                   Montefiore New Rochelle Hospital
# 61              4230                                    Oswego Hospital
# 132             6982       New York Community Hospital of Brooklyn, Inc
# 100             6650                             Putnam Hospital Center
# 152            22051   Memorial Hospital for Cancer and Allied Diseases
# 140             8440                   Kingsbrook Jewish Medical Center
# ..               ...                                                ...
# 27             18918                                  Highland Hospital
# 148            11837                             Harlem Hospital Center
# 121            20327                              Jacobi Medical Center
# 115             9852                      Northern Westchester Hospital
# 41              4370  United Health Services Hospitals Inc. - Bingha...
# 84              3985                                St. Mary's Hospital
# 70             24662                                 St Peters Hospital
# 39              5315                    Newark-Wayne Community Hospital
# 122            16929       Montefiore Medical Center-Wakefield Hospital
# 124            24229             Lincoln Medical & Mental Health Center
# 126            16585                                  SBH Health System
# 151            31778                                Lenox Hill Hospital
# 53              1518                    Community Memorial Hospital Inc
# 146            27532                           Bellevue Hospital Center
# 50              1023                         Carthage Area Hospital Inc
# 191            10208                                St Charles Hospital
# 157            31795                               NYU Hospitals Center
# 62              2943                     Claxton-Hepburn Medical Center
# 51              1641                      Lewis County General Hospital
# 159            26534                              Mount Sinai Roosevelt
# 128             5432                       North Central Bronx Hospital
# 154            11613                       Metropolitan Hospital Center
# 7              12742           Women And Children's Hospital Of Buffalo
# 174            17042  Long Island Jewish Schneiders Children's Hospi...
# 88              2310       Sunnyview Hospital and Rehabilitation Center
# 92              2312                            The Burdett Care Center
# 196             3475           Abortion Record - Facility Name Redacted
# 89              5503  Ellis Hospital - Bellevue Woman's Care Center ...
# 149             6129                    NYU Hospital for Joint Diseases
# 150            14532                       Hospital for Special Surgery
#
#      expired_count  expired_rate_per_discharge
# 125           2391                    0.824483
# 143            483                    0.047704
# 184            275                    0.045734
# 167            403                    0.045362
# 32             165                    0.045305
# 87             632                    0.044664
# 18              70                    0.040369
# 14             159                    0.040182
# 12             303                    0.039284
# 9              828                    0.039082
# 59             745                    0.037808
# 6              825                    0.037623
# 187            515                    0.037427
# 107            283                    0.036305
# 33              81                    0.036209
# 168           1046                    0.033506
# 94             676                    0.033297
# 130            522                    0.033007
# 1              171                    0.032497
# 10             145                    0.032468
# 44             160                    0.032103
# 185            275                    0.031884
# 83             304                    0.031186
# 133            481                    0.031161
# 112            230                    0.030540
# 61             128                    0.030260
# 132            210                    0.030077
# 100            198                    0.029774
# 152            650                    0.029477
# 140            247                    0.029265
# ..             ...                         ...
# 27             256                    0.013532
# 148            157                    0.013263
# 121            256                    0.012594
# 115            124                    0.012586
# 41              55                    0.012586
# 84              50                    0.012547
# 70             301                    0.012205
# 39              63                    0.011853
# 122            200                    0.011814
# 124            285                    0.011763
# 126            194                    0.011697
# 151            348                    0.010951
# 53              15                    0.009881
# 146            266                    0.009661
# 50               9                    0.008798
# 191             83                    0.008131
# 157            252                    0.007926
# 62              23                    0.007815
# 51              12                    0.007313
# 159            168                    0.006331
# 128             29                    0.005339
# 154             55                    0.004736
# 7               60                    0.004709
# 174             75                    0.004401
# 88               8                    0.003463
# 92               2                    0.000865
# 196              2                    0.000576
# 89               1                    0.000182
# 149              1                    0.000163
# 150              1                    0.000069
#
# [174 rows x 4 columns]

# %%
hospital_url = base_url + "?facility_name=Coney%20Island%20Hospital&$limit=50000"
print(hospital_url)
hospital_df = pd.read_json(hospital_url)
# Out:
# https://health.data.ny.gov/resource/rmwa-zns4?facility_name=Coney%20Island%20Hospital&$limit=50000

# %%
# Uncomment the last line if there are API issues
#hospital_df.to_csv("./data/sparcs_hospital_apr_drg_2014.csv")
#hospital_df = pd.read_csv("./data/sparcs_hospital_apr_drg_2014.csv")

# %%
hospital_df.head(10)
# Out:
#    Unnamed: 0 abortion_edit_indicator admit_day_of_week    age_group  \
# 0           0                       N               WED     30 to 49
# 1           1                       N               WED     50 to 69
# 2           2                       N               WED     30 to 49
# 3           3                       N               WED  70 or Older
# 4           4                       N               WED  70 or Older
# 5           5                       N               WED     50 to 69
# 6           6                       N               WED     30 to 49
# 7           7                       N               WED  70 or Older
# 8           8                       N               WED     30 to 49
# 9           9                       N               WED  70 or Older
#
#    apr_drg_code                    apr_drg_description  apr_mdc_code  \
# 0           753                      BIPOLAR DISORDERS            19
# 1           750                          SCHIZOPHRENIA            19
# 2           140  CHRONIC OBSTRUCTIVE PULMONARY DISEASE             4
# 3           720   SEPTICEMIA & DISSEMINATED INFECTIONS            18
# 4           140  CHRONIC OBSTRUCTIVE PULMONARY DISEASE             4
# 5           190            ACUTE MYOCARDIAL INFARCTION             5
# 6           750                          SCHIZOPHRENIA            19
# 7           463      KIDNEY & URINARY TRACT INFECTIONS            11
# 8           750                          SCHIZOPHRENIA            19
# 9           720   SEPTICEMIA & DISSEMINATED INFECTIONS            18
#
#                                  apr_mdc_description  \
# 0                      Mental Diseases and Disorders
# 1                      Mental Diseases and Disorders
# 2   Diseases and Disorders of the Respiratory System
# 3  Infectious and Parasitic Diseases, Systemic or...
# 4   Diseases and Disorders of the Respiratory System
# 5   Diseases and Disorders of the Circulatory System
# 6                      Mental Diseases and Disorders
# 7  Diseases and Disorders of the Kidney and Urina...
# 8                      Mental Diseases and Disorders
# 9  Infectious and Parasitic Diseases, Systemic or...
#
#   apr_medical_surgical_description apr_risk_of_mortality        ...          \
# 0                          Medical                 Minor        ...
# 1                          Medical                 Minor        ...
# 2                          Medical                 Minor        ...
# 3                          Medical                 Major        ...
# 4                          Medical                 Major        ...
# 5                          Medical                 Major        ...
# 6                          Medical                 Minor        ...
# 7                          Medical              Moderate        ...
# 8                          Medical                 Minor        ...
# 9                          Medical               Extreme        ...
#
#    operating_provider_license_number           patient_disposition  \
# 0                           234646.0             Home or Self Care
# 1                           218003.0             Home or Self Care
# 2                           235776.0             Home or Self Care
# 3                           217963.0          Skilled Nursing Home
# 4                           221582.0             Home or Self Care
# 5                           199382.0           Short-term Hospital
# 6                           204304.0             Home or Self Care
# 7                           241803.0  Home w/ Home Health Services
# 8                           218003.0             Home or Self Care
# 9                           235776.0          Skilled Nursing Home
#
#                      race  source_of_payment_1  source_of_payment_2  \
# 0              Other Race             Medicaid             Medicaid
# 1              Other Race             Medicare             Medicaid
# 2  Black/African American             Medicare             Medicare
# 3                   White             Medicare             Medicaid
# 4  Black/African American             Medicare             Medicare
# 5                   White             Medicare                  NaN
# 6              Other Race             Medicaid                  NaN
# 7                   White             Medicare             Medicare
# 8                   White             Self-Pay                  NaN
# 9                   White             Medicare             Medicare
#
#         source_of_payment_3  total_charges total_costs type_of_admission  \
# 0                       NaN       23450.98    17820.05         Emergency
# 1                       NaN       30716.00    23340.63         Emergency
# 2                  Medicaid       30174.63    22929.25         Emergency
# 3                       NaN       30204.59    22952.01         Emergency
# 4                  Medicaid       26651.11    20251.78         Emergency
# 5                       NaN       10611.60     8063.60         Emergency
# 6                       NaN       20958.05    15925.71         Emergency
# 7                  Medicaid       27150.89    20631.55         Emergency
# 8                       NaN       15168.03    11525.96         Emergency
# 9  Private Health Insurance       30454.78    23142.13         Emergency
#
#    zip_code_3_digits
# 0                112
# 1                112
# 2                112
# 3                112
# 4                112
# 5                112
# 6                112
# 7                112
# 8                112
# 9                112
#
# [10 rows x 39 columns]

# %% [markdown]
# We create a new column in the dataframe which contains the DRG and the description.

# %%
hospital_df["apr_drg_with_code"] = hospital_df.apply(
    lambda x: str("00" + str(int(x["apr_drg_code"])))[-3:] + " - " + x["apr_drg_description"], axis=1)

# %% [markdown]
# For hospital stays longer than 120 days are coded as `"120 +"`. We convert these to 120 days so we can convert the values into a numeric values.

# %%
hospital_df["length_of_stay"] = hospital_df.apply(
    lambda x: 120 if "120 +" == x["length_of_stay"] else int(x["length_of_stay"]), axis=1)

# %%
hospital_df["length_of_stay"].count()
# Out:
# 15436

# %% [markdown]
# We need to separately group the data for all discharges and for the mortality data.

# %%
import numpy as np
apr_drgs_df = hospital_df.groupby("apr_drg_with_code")["length_of_stay"].agg({"discharges": np.size, "total_days": np.sum, 
                                                                "mean_length_of_stay": np.mean})

# %%
apr_drgs_expired_df=hospital_df[hospital_df["patient_disposition"] == "Expired"].groupby("apr_drg_with_code")["length_of_stay"].agg({"number_of_in_hospital_deaths": np.size})

# %%
merged_apr_drgs_df = pd.merge(apr_drgs_df.reset_index(level=["apr_drg_with_code"]),apr_drgs_expired_df.reset_index(level=["apr_drg_with_code"]), on="apr_drg_with_code")

# %%
merged_apr_drgs_df.head(5)
# Out:
#                                    apr_drg_with_code  discharges  total_days  \
# 0  004 - TRACHEOSTOMY W MV 96+ HOURS W EXTENSIVE ...           9         524
# 1  005 - TRACHEOSTOMY W MV 96+ HOURS W/O EXTENSIV...          58        2901
# 2                        020 - CRANIOTOMY FOR TRAUMA          13         142
# 3                 021 - CRANIOTOMY EXCEPT FOR TRAUMA          27         624
# 4             024 - EXTRACRANIAL VASCULAR PROCEDURES           6          17
#
#    mean_length_of_stay  number_of_in_hospital_deaths
# 0            58.222222                             4
# 1            50.017241                            16
# 2            10.923077                             2
# 3            23.111111                             5
# 4             2.833333                             1

# %%
merged_apr_drgs_df.apr_drg_with_code.count()
# Out:
# 90

# %%
merged_apr_drgs_df["number_hospital_deaths_per_discharge"] = merged_apr_drgs_df["number_of_in_hospital_deaths"] / merged_apr_drgs_df["discharges"]

# %%
merged_apr_drgs_df["number_hospital_deaths_per_patient_days"] = merged_apr_drgs_df["number_of_in_hospital_deaths"] / merged_apr_drgs_df["total_days"]

# %%
merged_apr_drgs_df.sort_values("number_hospital_deaths_per_discharge", ascending=False)[merged_apr_drgs_df["discharges"] >= 10]
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#                                     apr_drg_with_code  discharges  total_days  \
# 24                               196 - CARDIAC ARREST          13          37
# 13  130 - RESPIRATORY SYSTEM DIAGNOSIS W VENTILATO...          41         907
# 6                       044 - INTRACRANIAL HEMORRHAGE          44         365
# 45  281 - MALIGNANCY OF HEPATOBILIARY SYSTEM & PAN...          19         266
# 74         720 - SEPTICEMIA & DISSEMINATED INFECTIONS         563        6977
# 8                    052 - NONTRAUMATIC STUPOR & COMA          28         188
# 1   005 - TRACHEOSTOMY W MV 96+ HOURS W/O EXTENSIV...          58        2901
# 16                       136 - RESPIRATORY MALIGNANCY          20         357
# 3                  021 - CRANIOTOMY EXCEPT FOR TRAUMA          27         624
# 72  710 - INFECTIOUS & PARASITIC DISEASES INCLUDIN...          43        1114
# 2                         020 - CRANIOTOMY FOR TRAUMA          13         142
# 36                         240 - DIGESTIVE MALIGNANCY          21         256
# 5                     041 - NERVOUS SYSTEM MALIGNANCY          14         212
# 12         121 - OTHER RESPIRATORY & CHEST PROCEDURES          14         209
# 14        133 - PULMONARY EDEMA & RESPIRATORY FAILURE         113        1164
# 53                  346 - CONNECTIVE TISSUE DISORDERS          15         259
# 62  421 - MALNUTRITION, FAILURE TO THRIVE & OTHER ...          31         232
# 17  137 - MAJOR RESPIRATORY INFECTIONS & INFLAMMAT...          66         702
# 37                   242 - MAJOR ESOPHAGEAL DISORDERS          30         175
# 32           207 - OTHER CIRCULATORY SYSTEM DIAGNOSES          61         305
# 80  815 - OTHER INJURY, POISONING & TOXIC EFFECT D...          22         176
# 48  304 - DORSAL & LUMBAR FUSION PROC EXCEPT FOR C...          11         120
# 15                           134 - PULMONARY EMBOLISM          33         277
# 86  890 - HIV W MULTIPLE MAJOR HIV RELATED CONDITIONS          12         341
# 78                776 - OTHER DRUG ABUSE & DEPENDENCE          12          54
# 89  952 - NONEXTENSIVE PROCEDURE UNRELATED TO PRIN...          25         410
# 79                812 - POISONING OF MEDICINAL AGENTS          69         369
# 7         045 - CVA & PRECEREBRAL OCCLUSION W INFARCT         211        1825
# 88  950 - EXTENSIVE PROCEDURE UNRELATED TO PRINCIP...          15         314
# 41  253 - OTHER & UNSPECIFIED GASTROINTESTINAL HEM...         108         685
# ..                                                ...         ...         ...
# 21                  190 - ACUTE MYOCARDIAL INFARCTION         119         610
# 81    816 - TOXIC EFFECTS OF NON-MEDICINAL SUBSTANCES          64         381
# 20  143 - OTHER RESPIRATORY DIAGNOSES EXCEPT SIGNS...          32         232
# 23                                194 - HEART FAILURE         495        3932
# 59  385 - OTHER SKIN, SUBCUTANEOUS TISSUE & BREAST...          35         127
# 28    201 - CARDIAC ARRHYTHMIA & CONDUCTION DISORDERS         187         976
# 46      282 - DISORDERS OF PANCREAS EXCEPT MALIGNANCY         118         759
# 77                   774 - COCAINE ABUSE & DEPENDENCE          46         247
# 49  308 - HIP & FEMUR PROCEDURES FOR TRAUMA EXCEPT...          96        1072
# 47                        301 - HIP JOINT REPLACEMENT          50         508
# 18                              139 - OTHER PNEUMONIA         312        2376
# 42             254 - OTHER DIGESTIVE SYSTEM DIAGNOSES         161         660
# 38                       247 - INTESTINAL OBSTRUCTION          56         310
# 76           757 - ORGANIC MENTAL HEALTH DISTURBANCES          58         597
# 44                      280 - ALCOHOLIC LIVER DISEASE          61         402
# 22  191 - CARDIAC CATHETERIZATION W CIRC DISORD EX...          63         595
# 67  468 - OTHER KIDNEY & URINARY TRACT DIAGNOSES, ...          68         459
# 19        140 - CHRONIC OBSTRUCTIVE PULMONARY DISEASE         296        1771
# 54  347 - OTHER BACK & NECK DISORDERS, FRACTURES &...          77         483
# 27                                 199 - HYPERTENSION         100         419
# 9                                       053 - SEIZURE         242        1169
# 84                               860 - REHABILITATION         134        2234
# 58  383 - CELLULITIS & OTHER BACTERIAL SKIN INFECT...         269        1673
# 65            463 - KIDNEY & URINARY TRACT INFECTIONS         280        1919
# 55  351 - OTHER MUSCULOSKELETAL SYSTEM & CONNECTIV...         147         843
# 39  249 - NON-BACTERIAL GASTROENTERITIS, NAUSEA & ...         161         809
# 30                           204 - SYNCOPE & COLLAPSE         391        1914
# 29                                   203 - CHEST PAIN         197         645
# 61                                     420 - DIABETES         199         890
# 26   198 - ANGINA PECTORIS & CORONARY ATHEROSCLEROSIS         223         918
#
#     mean_length_of_stay  number_of_in_hospital_deaths  \
# 24             2.846154                            11
# 13            22.121951                            20
# 6              8.295455                            14
# 45            14.000000                             6
# 74            12.392540                           177
# 8              6.714286                             8
# 1             50.017241                            16
# 16            17.850000                             4
# 3             23.111111                             5
# 72            25.906977                             7
# 2             10.923077                             2
# 36            12.190476                             3
# 5             15.142857                             2
# 12            14.928571                             2
# 14            10.300885                            16
# 53            17.266667                             2
# 62             7.483871                             4
# 17            10.636364                             7
# 37             5.833333                             3
# 32             5.000000                             6
# 80             8.000000                             2
# 48            10.909091                             1
# 15             8.393939                             3
# 86            28.416667                             1
# 78             4.500000                             1
# 89            16.400000                             2
# 79             5.347826                             5
# 7              8.649289                            15
# 88            20.933333                             1
# 41             6.342593                             7
# ..                  ...                           ...
# 21             5.126050                             4
# 81             5.953125                             2
# 20             7.250000                             1
# 23             7.943434                            15
# 59             3.628571                             1
# 28             5.219251                             5
# 46             6.432203                             3
# 77             5.369565                             1
# 49            11.166667                             2
# 47            10.160000                             1
# 18             7.615385                             6
# 42             4.099379                             3
# 38             5.535714                             1
# 76            10.293103                             1
# 44             6.590164                             1
# 22             9.444444                             1
# 67             6.750000                             1
# 19             5.983108                             4
# 54             6.272727                             1
# 27             4.190000                             1
# 9              4.830579                             2
# 84            16.671642                             1
# 58             6.219331                             2
# 65             6.853571                             2
# 55             5.734694                             1
# 39             5.024845                             1
# 30             4.895141                             2
# 29             3.274112                             1
# 61             4.472362                             1
# 26             4.116592                             1
#
#     number_hospital_deaths_per_discharge  \
# 24                              0.846154
# 13                              0.487805
# 6                               0.318182
# 45                              0.315789
# 74                              0.314387
# 8                               0.285714
# 1                               0.275862
# 16                              0.200000
# 3                               0.185185
# 72                              0.162791
# 2                               0.153846
# 36                              0.142857
# 5                               0.142857
# 12                              0.142857
# 14                              0.141593
# 53                              0.133333
# 62                              0.129032
# 17                              0.106061
# 37                              0.100000
# 32                              0.098361
# 80                              0.090909
# 48                              0.090909
# 15                              0.090909
# 86                              0.083333
# 78                              0.083333
# 89                              0.080000
# 79                              0.072464
# 7                               0.071090
# 88                              0.066667
# 41                              0.064815
# ..                                   ...
# 21                              0.033613
# 81                              0.031250
# 20                              0.031250
# 23                              0.030303
# 59                              0.028571
# 28                              0.026738
# 46                              0.025424
# 77                              0.021739
# 49                              0.020833
# 47                              0.020000
# 18                              0.019231
# 42                              0.018634
# 38                              0.017857
# 76                              0.017241
# 44                              0.016393
# 22                              0.015873
# 67                              0.014706
# 19                              0.013514
# 54                              0.012987
# 27                              0.010000
# 9                               0.008264
# 84                              0.007463
# 58                              0.007435
# 65                              0.007143
# 55                              0.006803
# 39                              0.006211
# 30                              0.005115
# 29                              0.005076
# 61                              0.005025
# 26                              0.004484
#
#     number_hospital_deaths_per_patient_days
# 24                                 0.297297
# 13                                 0.022051
# 6                                  0.038356
# 45                                 0.022556
# 74                                 0.025369
# 8                                  0.042553
# 1                                  0.005515
# 16                                 0.011204
# 3                                  0.008013
# 72                                 0.006284
# 2                                  0.014085
# 36                                 0.011719
# 5                                  0.009434
# 12                                 0.009569
# 14                                 0.013746
# 53                                 0.007722
# 62                                 0.017241
# 17                                 0.009972
# 37                                 0.017143
# 32                                 0.019672
# 80                                 0.011364
# 48                                 0.008333
# 15                                 0.010830
# 86                                 0.002933
# 78                                 0.018519
# 89                                 0.004878
# 79                                 0.013550
# 7                                  0.008219
# 88                                 0.003185
# 41                                 0.010219
# ..                                      ...
# 21                                 0.006557
# 81                                 0.005249
# 20                                 0.004310
# 23                                 0.003815
# 59                                 0.007874
# 28                                 0.005123
# 46                                 0.003953
# 77                                 0.004049
# 49                                 0.001866
# 47                                 0.001969
# 18                                 0.002525
# 42                                 0.004545
# 38                                 0.003226
# 76                                 0.001675
# 44                                 0.002488
# 22                                 0.001681
# 67                                 0.002179
# 19                                 0.002259
# 54                                 0.002070
# 27                                 0.002387
# 9                                  0.001711
# 84                                 0.000448
# 58                                 0.001195
# 65                                 0.001042
# 55                                 0.001186
# 39                                 0.001236
# 30                                 0.001045
# 29                                 0.001550
# 61                                 0.001124
# 26                                 0.001089
#
# [74 rows x 7 columns]

# %% [markdown]
# This analysis could be extended by computing the APR DRGs based mortality across one or more hospitals. That would allow an analyst to compare the rate at one facility agains
